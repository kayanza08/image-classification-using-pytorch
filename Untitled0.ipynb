# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=128,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=100,
                                         shuffle=False, num_workers=2)

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, 3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, 3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.conv4 = nn.Conv2d(256, 512, 3, padding=1)
        self.bn4 = nn.BatchNorm2d(512)
        self.conv5 = nn.Conv2d(512, 512, 3, padding=1)
        self.bn5 = nn.BatchNorm2d(512)
        self.conv6 = nn.Conv2d(512, 512, 3, padding=1)
        self.bn6 = nn.BatchNorm2d(512)

        self.pool = nn.MaxPool2d(2,2)
        self.dropout = nn.Dropout(0.5)

        self.fc1 = nn.Linear(512*1*1, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = self.pool(F.relu(self.bn3(self.conv3(x))))
        x = self.pool(F.relu(self.bn4(self.conv4(x))))
        x = self.pool(F.relu(self.bn5(self.conv5(x))))
        x = F.relu(self.bn6(self.conv6(x)))

        x = x.view(-1, 512*1*1)
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.dropout(F.relu(self.fc2(x)))
        x = self.fc3(x)
        return x


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = Net().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001, weight_decay=1e-4)

scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=25, eta_min=1e-5)


train_acc_list, test_acc_list = [], []

epochs = 25
for epoch in range(epochs):
    net.train()
    running_loss, correct, total = 0.0, 0, 0

    for inputs, labels in trainloader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

    scheduler.step()
    train_acc = 100 * correct / total
    train_acc_list.append(train_acc)


    net.eval()
    correct_test, total_test = 0, 0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = net(inputs)
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_acc = 100 * correct_test / total_test
    test_acc_list.append(test_acc)

    print(f"Epoch {epoch+1}, Train Acc: {train_acc:.2f}%, Test Acc: {test_acc:.2f}%, LR: {scheduler.get_last_lr()[0]:.6f}")

plt.figure(figsize=(10,5))
plt.plot(range(1, epochs+1), train_acc_list, label='Train Accuracy')
plt.plot(range(1, epochs+1), test_acc_list, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.title('Training and Test Accuracy with CosineAnnealingLR')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1, Train Acc: 44.06%, Test Acc: 51.49%, LR: 0.000996
# Epoch 2, Train Acc: 60.89%, Test Acc: 64.98%, LR: 0.000984
# Epoch 3, Train Acc: 66.95%, Test Acc: 66.71%, LR: 0.000965
# Epoch 4, Train Acc: 70.97%, Test Acc: 71.94%, LR: 0.000939
# Epoch 5, Train Acc: 74.16%, Test Acc: 73.29%, LR: 0.000905
# Epoch 6, Train Acc: 76.18%, Test Acc: 74.53%, LR: 0.000866
# Epoch 7, Train Acc: 77.91%, Test Acc: 73.95%, LR: 0.000821
# Epoch 8, Train Acc: 79.75%, Test Acc: 74.19%, LR: 0.000770
# Epoch 9, Train Acc: 81.02%, Test Acc: 80.84%, LR: 0.000716
# Epoch 10, Train Acc: 82.26%, Test Acc: 78.12%, LR: 0.000658
# Epoch 11, Train Acc: 83.47%, Test Acc: 81.13%, LR: 0.000598
# Epoch 12, Train Acc: 84.55%, Test Acc: 81.79%, LR: 0.000536
# Epoch 13, Train Acc: 85.64%, Test Acc: 81.01%, LR: 0.000474
# Epoch 14, Train Acc: 86.55%, Test Acc: 83.61%, LR: 0.000412
# Epoch 15, Train Acc: 87.32%, Test Acc: 84.90%, LR: 0.000352
# Epoch 16, Train Acc: 88.42%, Test Acc: 84.59%, LR: 0.000294
# Epoch 17, Train Acc: 89.26%, Test Acc: 85.45%, LR: 0.000240
# Epoch 18, Train Acc: 89.93%, Test Acc: 84.91%, LR: 0.000189
# Epoch 19, Train Acc: 90.83%, Test Acc: 85.97%, LR: 0.000144
# Epoch 20, Train Acc: 91.53%, Test Acc: 86.50%, LR: 0.000105
# Epoch 21, Train Acc: 91.93%, Test Acc: 86.59%, LR: 0.000071
# Epoch 22, Train Acc: 92.42%, Test Acc: 87.66%, LR: 0.000045
# Epoch 23, Train Acc: 92.80%, Test Acc: 87.26%, LR: 0.000026
# Epoch 24, Train Acc: 93.18%, Test Acc: 87.64%, LR: 0.000014
# Epoch 25, Train Acc: 93.17%, Test Acc: 87.39%, LR: 0.000010

# %%
import matplotlib.pyplot as plt
import torchvision
import numpy as np

classes = ['plane','car','bird','cat','deer','dog','frog','horse','ship','truck']

dataiter = iter(testloader)
images, labels = next(dataiter)
images, labels = images.to(device), labels.to(device)

net.eval()
with torch.no_grad():
    outputs = net(images)
    _, predicted = torch.max(outputs, 1)


plt.figure(figsize=(12,4))
for i in range(5):
    img = images[i].cpu()
    img = img / 2 + 0.5
    npimg = img.numpy()
    plt.subplot(1,5,i+1)
    plt.imshow(np.transpose(npimg, (1,2,0)))
    plt.title(f"P: {classes[predicted[i]]}\nT: {classes[labels[i]]}")
    plt.axis('off')
plt.show()
